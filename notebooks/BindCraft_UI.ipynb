# %% [markdown]
# # BindCraft Interactive UI
#
# This notebook provides the interactive `ipywidgets` interface for uploading target structures, editing target settings, selecting filter and advanced settings, and launching BindCraft jobs.

# %%
# %pip install -q 'ipywidgets>=8' jupyterlab_widgets widgetsnbextension
import ipywidgets
print(f'ipywidgets {ipywidgets.__version__} OK')
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ipywidgets 8.1.9 OK

# %%
import sys
from pathlib import Path

ROOT = Path.cwd().resolve()
if not (ROOT / 'main_UI.py').exists():
    ROOT = Path('/storage/viet/BindCraft').resolve()
sys.path.insert(0, str(ROOT))

from main_UI import launch_all_ui

launch_all_ui()

# %% [markdown]
# ## Zip outputs for download
#
# After a run, download or archive the selected design folder from the file browser.

# %%
# go to the project root
# !cd /storage/viet/BindCraft

# zip the outputs folder
# !zip -r outputs.zip outputs
